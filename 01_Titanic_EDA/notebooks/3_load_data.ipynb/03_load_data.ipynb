# %%
# Notebook 3: Load Data

# Use relative paths based on your project structure
train = pd.read_csv("../Data/raw/train.csv")
test = pd.read_csv("../Data/raw/test.csv")

# Check the first few rows
train.head()
test.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 # Notebook 3: Load Data
#       2
#       3 # Use relative paths based on your project structure
# ----> 4 train = pd.read_csv("../Data/raw/train.csv")
#       5 test = pd.read_csv("../Data/raw/test.csv")
#       7 # Check the first few rows
#
# NameError: name 'pd' is not defined

# %%
train = pd.read_csv(r"C:\Users\HP\Documents\GitHub\DataMining-Portfolio\01_Titanic_EDA\Data\raw\train.csv")
test = pd.read_csv(r"C:\Users\HP\Documents\GitHub\DataMining-Portfolio\01_Titanic_EDA\Data\raw\test.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 train = pd.read_csv(r"C:\Users\HP\Documents\GitHub\DataMining-Portfolio\01_Titanic_EDA\Data\raw\train.csv")
#       2 test = pd.read_csv(r"C:\Users\HP\Documents\GitHub\DataMining-Portfolio\01_Titanic_EDA\Data\raw\test.csv")
#
# NameError: name 'pd' is not defined
