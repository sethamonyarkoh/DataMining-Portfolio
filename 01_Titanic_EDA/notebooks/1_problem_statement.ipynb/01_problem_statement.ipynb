# %%
# Titanic EDA
# Step 1: Define the problem
# Objective: Explore Titanic data and understand survival patterns

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\HP\\Documents\\GitHub\\DataMining-Portfolio\\01_Titanic_EDA\\notebooks\\1_problem_statement.ipynb'

# %%
train = pd.read_csv(r"C:\Users\HP\Documents\GitHub\DataMining-Portfolio\01_Titanic_EDA\Data\raw\train.csv")
test = pd.read_csv(r"C:\Users\HP\Documents\GitHub\DataMining-Portfolio\01_Titanic_EDA\Data\raw\test.csv")

# %%
train.head()
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S
