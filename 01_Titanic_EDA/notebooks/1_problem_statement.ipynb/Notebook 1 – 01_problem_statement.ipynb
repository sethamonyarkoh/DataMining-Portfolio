# %%
# Titanic Exploratory Data Analysis
# Notebook 1: Problem Statement

# Objective:
# Explore the Titanic dataset to understand factors influencing survival
# and prepare insights for reporting.

# Questions we want to answer:
# 1. Which factors (gender, age, class, etc.) affect survival the most?
# 2. Are there correlations between features?
# 3. Can we predict survival (optional)?

# Dataset source: Kaggle Titanic competition
